// %% [markdown]
// # Jyve JavaScript
// Just like it says on the tin, this runs whatever JavaScript your browser can currently support.

// %%
x = 1
// Out:
// 1

// %%
++x
// Out:
// 2

// %%
JSON.stringify(x)
// Out:
// 2

// %% [markdown]
// Modern browsers support:
// - the [`class` keyword](https://caniuse.com/#feat=es6-class) for inheritance without `prototype`
// -
// ```
// `${string} templates`
// ``` for concise string manipulation
// - [`async/await` keywords](https://caniuse.com/#feat=async-functions) for asynchronous code
// - and more!

// %%
class Adder {
    add(a, b) {
        document.write(
            `🐍 says <i>${a} plussss ${b} issss ${a + b}</i><br/>`
        )
        return a + b;
    }
}
this.Adder = Adder
// Out:
// class Adder {
//     add(a, b) {
//         document.write(
//             `🐍 says <i>${a} plussss ${b} issss ${a + b}</i><br/>`
//         )
//         return a + b;
//     }
// }

// %%
var it = new this.Adder();
it.add(1, 1)
// Out:
// 2

// %%
sir_not_appearing_in_this_notebook
// Out:
// ReferenceError: sir_not_appearing_in_this_notebook is not defined
// ReferenceError: sir_not_appearing_in_this_notebook is not defined
//     at eval (eval at <anonymous> (http://localhost:8889/lab/static/main.396c2eb4aa5dd87809a9.js:82008:53), <anonymous>:1:1)
//     at eval (<anonymous>)
//     at Object.<anonymous> (http://localhost:8889/lab/static/main.396c2eb4aa5dd87809a9.js:82008:53)
//     at http://localhost:8889/lab/static/main.396c2eb4aa5dd87809a9.js:82009:36
//     at new Promise (<anonymous>)
//     at JSUnsafeKernel.<anonymous> (http://localhost:8889/lab/static/main.396c2eb4aa5dd87809a9.js:82001:47)
//     at step (http://localhost:8889/lab/static/main.396c2eb4aa5dd87809a9.js:45985:23)
//     at Object.next (http://localhost:8889/lab/static/main.396c2eb4aa5dd87809a9.js:45966:53)
//     at fulfilled (http://localhost:8889/lab/static/main.396c2eb4aa5dd87809a9.js:45956:58)
//     at <anonymous>
